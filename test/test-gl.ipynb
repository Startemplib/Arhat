# %%
import inspect

# Test the type and dimensions (depth and elements per level) of variables
def gl(*variables):
    frame = inspect.currentframe().f_back
    variable_names = {id(v): name for name, v in frame.f_locals.items() if id(v) in map(id, variables)}
    
    # Function to detect dimensions (depth and elements per level) of nested lists or tuples
    def get_dimensions(item, level=0, dims=None):
        if dims is None:
            dims = {}

        if isinstance(item, (list, tuple)):
            # If the current level is not recorded yet, initialize it
            if level not in dims:
                dims[level] = 0
            dims[level] += len(item)

            # Recursively calculate dimensions for the nested elements
            for sub_item in item:
                get_dimensions(sub_item, level + 1, dims)

        return dims

    for var in variables:
        var_name = variable_names.get(id(var), "Unknown")
        print(f"Variable '{var_name}':")
        print(f"  Type: {type(var).__name__}")  # Cleaned output for the type
        
        # If the variable is a list or tuple, calculate its dimensions (depth and elements per level)
        if isinstance(var, (list, tuple)):
            dimensions = get_dimensions(var)
            print(f"  Dimensions (Depth: {len(dimensions)} levels): {dimensions}")
        
        # If the variable has a 'shape' attribute (like NumPy arrays or pandas DataFrames)
        elif hasattr(var, 'shape'):
            print(f"  Shape: {var.shape}")
        
        else:
            print(f"  Shape: lemeow~")
        
        print(f"  Value: {var}\n")
        
# Example variables for testing
hts = [[1, 2], [3, 4]]
ts = [1, 2, 3]
dt = 0.1
iterations = 1000
p = [1, 2, 3]
f = (786, 2.23, "string", (1.2234, 423))
g = [["gold", 2], [3, 1, 3, [2, 3], 4]]

# Call the function with your variables
gl(hts, p, f, g, ts, dt, iterations)
# Out:
# Variable 'hts':
#   Type: list
#   Dimensions (Depth: 2 levels): {0: 2, 1: 4}
#   Value: [[1, 2], [3, 4]]
#
# Variable 'p':
#   Type: list
#   Dimensions (Depth: 1 levels): {0: 3}
#   Value: [1, 2, 3]
#
# Variable 'f':
#   Type: tuple
#   Dimensions (Depth: 2 levels): {0: 4, 1: 2}
#   Value: (786, 2.23, 'string', (1.2234, 423))
#
# Variable 'g':
#   Type: list
#   Dimensions (Depth: 3 levels): {0: 2, 1: 7, 2: 2}
#   Value: [['gold', 2], [3, 1, 3, [2, 3], 4]]
#
# Variable 'ts':
#   Type: list
#   Dimensions (Depth: 1 levels): {0: 3}
#   Value: [1, 2, 3]
#
# Variable 'dt':
#   Type: float
#   Shape: lemeow~
#   Value: 0.1
#
# Variable 'iterations':
#   Type: int
#   Shape: lemeow~
#   Value: 1000

# %%
import inspect
import sympy as sp

# Test the type and dimensions (depth and elements per level) of variables
def gl(*variables):
    frame = inspect.currentframe().f_back
    variable_names = {id(v): name for name, v in frame.f_locals.items() if id(v) in map(id, variables)}
    
    # Function to detect dimensions (depth and elements per level) of nested lists or tuples
    def get_dimensions(item, level=0, dims=None):
        if dims is None:
            dims = {}

        if isinstance(item, (list, tuple)):
            # If the current level is not recorded yet, initialize it
            if level not in dims:
                dims[level] = 0
            dims[level] += len(item)

            # Recursively calculate dimensions for the nested elements
            for sub_item in item:
                get_dimensions(sub_item, level + 1, dims)

        return dims

       # Function to collect all basic element types within lists, tuples, or SymPy matrices
    def get_element_types(item, element_types=None):
        if element_types is None:
            element_types = set()

        # Handle SymPy matrices and symbols separately
        if isinstance(item, (sp.Matrix, sp.ImmutableDenseMatrix, sp.MutableDenseMatrix)):
            for element in item:
                element_types.add(type(element).__name__)
        
        # Check for SymPy symbols
        elif isinstance(item, sp.Basic):  # This includes symbolic elements like sp.symbols
            element_types.add(type(item).__name__)
        
        elif isinstance(item, (list, tuple)):
            # Recursively get types of nested elements
            for sub_item in item:
                get_element_types(sub_item, element_types)
        else:
            # Add the type of the basic element
            element_types.add(type(item).__name__)

        return element_types

    for var in variables:
        var_name = variable_names.get(id(var), "Unknown")
        print(f"Name:                                                    '{var_name}'")
        print(f"  Type:                                                    {type(var).__name__}")  # Cleaned output for the type
        
        # If the variable is a list or tuple, calculate its dimensions and element types
        if isinstance(var, (list, tuple)):
            dimensions = get_dimensions(var)
            element_types = get_element_types(var)
            print(f"  Dimensions (Depth: {len(dimensions)}):                       {dimensions}")
            print(f"  Element Types:                                    {element_types}")
        
        # If the variable has a 'shape' attribute (like NumPy arrays or SymPy matrices), show shape
        elif hasattr(var, 'shape'):
            print(f"  Shape:                                                   {var.shape}")
            element_types = get_element_types(var)
            print(f"  Element Types:                                    {element_types}")
        
        else:
            print(f"  Shape:                                                   lemeow~")
        
        print(f"  Value:                                                   {var}\n")

# Example variables for testing
hts = [[1, 2], [3, 4]]
ts = [1, 2, 3, (3, 2)]
p = [1, 2, 3]
f = (786, 2.23, "string", (1.2234, 423))
g = [["gold", 2], [3, 1, 3, [2, 3], 4]]

# Define symbolic variables
x, y, z = sp.symbols('x y z')

# Test with SymPy matrices
its = sp.MutableDenseMatrix(160, 1, lambda i, j: sp.Rational(i + j, 255))
dts = sp.ImmutableDenseMatrix(160, 1, lambda i, j: sp.Rational(i - j, 512))
nH = sp.MutableDenseMatrix(160, 160, lambda i, j: sp.Rational(i * j, 255))
# SymPy matrix with symbolic elements
symbolic_matrix = sp.Matrix([[x, y, 1, 0], [y, z,1,2],[y, z,1,2],[y, 2+z,1,2+z]])

# Call the function with your variables
gl(hts, p, f, g, ts, its, dts, nH,1,"fsdfsd",symbolic_matrix )
# Out:
# Name:                                                    'hts'
#   Type:                                                    list
#   Dimensions (Depth: 2):                       {0: 2, 1: 4}
#   Element Types:                                    {'int'}
#   Value:                                                   [[1, 2], [3, 4]]
#
# Name:                                                    'p'
#   Type:                                                    list
#   Dimensions (Depth: 1):                       {0: 3}
#   Element Types:                                    {'int'}
#   Value:                                                   [1, 2, 3]
#
# Name:                                                    'f'
#   Type:                                                    tuple
#   Dimensions (Depth: 2):                       {0: 4, 1: 2}
#   Element Types:                                    {'int', 'float', 'str'}
#   Value:                                                   (786, 2.23, 'string', (1.2234, 423))
#
# Name:                                                    'g'
#   Type:                                                    list
#   Dimensions (Depth: 3):                       {0: 2, 1: 7, 2: 2}
#   Element Types:                                    {'int', 'str'}
#   Value:                                                   [['gold', 2], [3, 1, 3, [2, 3], 4]]
#   Value:                                                   Matrix([[x, y, 1, 0], [y, z, 1, 2], [y, z, 1, 2], [y, z + 2, 1, z + 2]])

# %%
import inspect
import sympy as sp

# Test the type and dimensions (depth and elements per level) of variables
def gl(*variables):
    frame = inspect.currentframe().f_back
    variable_names = {id(v): name for name, v in frame.f_locals.items() if id(v) in map(id, variables)}
    
    # Function to detect dimensions (depth and elements per level) of nested lists or tuples
    def get_dimensions(item, level=0, dims=None):
        if dims is None:
            dims = {}

        if isinstance(item, (list, tuple)):
            # If the current level is not recorded yet, initialize it
            if level not in dims:
                dims[level] = 0
            dims[level] += len(item)

            # Recursively calculate dimensions for the nested elements
            for sub_item in item:
                get_dimensions(sub_item, level + 1, dims)

        return dims

    # Function to collect all basic element types within lists, tuples, or SymPy matrices
    def get_element_types(item, element_types=None):
        if element_types is None:
            element_types = set()

        # Handle SymPy matrices and symbolic elements
        if isinstance(item, (sp.Matrix, sp.ImmutableDenseMatrix, sp.MutableDenseMatrix)):
            for element in item:
                element_types.add(type(element).__name__)
        
        # Check for SymPy symbolic expressions (Add, Mul, symbols, etc.)
        elif isinstance(item, sp.Basic):  # This includes symbolic expressions like Add, Mul
            element_types.add(type(item).__name__)
        
        elif isinstance(item, (list, tuple)):
            # Recursively get types of nested elements
            for sub_item in item:
                get_element_types(sub_item, element_types)
        else:
            # Add the type of the basic element
            element_types.add(type(item).__name__)

        return element_types

    for var in variables:
        var_name = variable_names.get(id(var), "Unknown")
        print(f"Name:                                  '{var_name}'")
        print(f"  Type:                                  {type(var).__name__}")  # Cleaned output for the type
        
        # If the variable is a list or tuple, calculate its dimensions and element types
        if isinstance(var, (list, tuple)):
            dimensions = get_dimensions(var)
            element_types = get_element_types(var)
            print(f"  Dimensions (Depth: {len(dimensions)}): {dimensions}")
            print(f"  Element Types:                        {element_types}")
        
        # If the variable has a 'shape' attribute (like NumPy arrays or SymPy matrices), show shape
        elif hasattr(var, 'shape'):
            print(f"  Shape:                                 {var.shape}")
            element_types = get_element_types(var)
            print(f"  Element Types:                        {element_types}")
        
        else:
            print(f"  Shape:                                 lemeow~")
        
        print(f"  Value:                                 {var}\n")

# Example code based on the symbols you've provided
L = 80
S = L * 2
n = 41
I = 7**2

# SymPy symbols and expressions
t, tau, kd, alpha = sp.symbols('t tau kd alpha', real=True)
v = sp.symbols(f"v0:{n}", real=True)  # Define v as a list of symbols
k = sp.symbols(f"k0:{n}", real=True)
kappa = sp.symbols(f"kappa0:{n}", real=True)
ar = sp.symbols(f"ar0:{L}", real=True)
ai = sp.symbols(f"ai0:{L}", real=True)
br = sp.symbols(f"br0:{L}", real=True)
bi = sp.symbols(f"bi0:{L}", real=True)

# Define complex elements aa, aac, bb, bbc
aa = [ar[i] + sp.I * ai[i] for i in range(L)]
aac = [ar[i] - sp.I * ai[i] for i in range(L)]
bb = [br[i] + sp.I * bi[i] for i in range(L)]
bbc = [br[i] - sp.I * bi[i] for i in range(L)]

# Constructing a matrix for `ts`
[I*ai59 + ar59], [I*bi59 + br59], [I*ai60 + ar60], [I*bi60 + br60], [I*ai61 + ar61], [I*bi61 + br61], [I*ai62 + ar62], [I*bi62 + br62], [I*ai63 + ar63], [I*bi63 + br63], [I*ai64 + ar64], [I*bi64 + br64], [I*ai65 + ar65], [I*bi65 + br65], [I*ai66 + ar66], [I*bi66 + br66], [I*ai67 + ar67], [I*bi67 + br67], [I*ai68 + ar68], [I*bi68 + br68], [I*ai69 + ar69], [I*bi69 + br69], [I*ai70 + ar70], [I*bi70 + br70], [I*ai71 + ar71], [I*bi71 + br71], [I*ai72 + ar72], [I*bi72 + br72], [I*ai73 + ar73], [I*bi73 + br73], [I*ai74 + ar74], [I*bi74 + br74], [I*ai75 + ar75], [I*bi75 + br75], [I*ai76 + ar76], [I*bi76 + br76], [I*ai77 + ar77], [I*bi77 + br77], [I*ai78 + ar78], [I*bi78 + br78], [I*ai79 + ar79], [I*bi79 + br79]])

# %%
import inspect
import sympy as sp

# Test the type and dimensions (depth and elements per level) of variables
def gl(*variables):
    frame = inspect.currentframe().f_back
    variable_names = {id(v): name for name, v in frame.f_locals.items() if id(v) in map(id, variables)}
    
    # Function to detect dimensions (depth and elements per level) of nested lists or tuples
    def get_dimensions(item, level=0, dims=None):
        if dims is None:
            dims = {}

        if isinstance(item, (list, tuple)):
            # If the current level is not recorded yet, initialize it
            if level not in dims:
                dims[level] = 0
            dims[level] += len(item)

            # Recursively calculate dimensions for the nested elements
            for sub_item in item:
                get_dimensions(sub_item, level + 1, dims)

        return dims

    # Function to analyze SymPy expressions and extract operation types and symbols
     # Function to analyze SymPy expressions and extract operation types and symbols
    def analyze_sympy_expression(expr, element_types):
        print(f"Analyzing: {expr} of type {type(expr)}")  # Debugging: print the expression and its type
        if isinstance(expr, sp.Basic):
            if expr.is_Add or expr.is_Mul or expr.is_Pow:
                element_types.add(type(expr).__name__)
                
                # Decompose the Add, Mul, or Pow into its arguments
                for arg in expr.args:
                    if isinstance(arg, sp.Basic):
                        print(f"  Sub-expression: {arg} of type {type(arg)}")  # Debugging: print each sub-expression
                        element_types.add(type(arg).__name__)  # Add sub-expression type
                        analyze_sympy_expression(arg, element_types)  # Recursively analyze the arguments
            else:
                # Collect the symbols involved in the expression
                for symbol in expr.free_symbols:
                    element_types.add(f'Symbol({symbol})')
                    
    # Function to collect all basic element types within lists, tuples, or SymPy matrices
    def get_element_types(item, element_types=None):
        if element_types is None:
            element_types = set()

        # Handle SymPy expressions (Add, Mul, symbols, etc.)
        if isinstance(item, (sp.Matrix, sp.ImmutableDenseMatrix, sp.MutableDenseMatrix)):
            for element in item:
                analyze_sympy_expression(element, element_types)
        
        elif isinstance(item, (list, tuple)):
            # Recursively get types of nested elements
            for sub_item in item:
                get_element_types(sub_item, element_types)
        else:
            # Add the type of the basic element
            element_types.add(type(item).__name__)

        return element_types
    
    for var in variables:
        var_name = variable_names.get(id(var), "Unknown")
        print(f"Name:                                  '{var_name}'")
        print(f"  Type:                                  {type(var).__name__}")  # Cleaned output for the type
        
        # If the variable is a list or tuple, calculate its dimensions and element types
        if isinstance(var, (list, tuple)):
            dimensions = get_dimensions(var)
            element_types = get_element_types(var)
            print(f"  Dimensions (Depth: {len(dimensions)}): {dimensions}")
            print(f"  Element Types:                        {element_types}")
        
        # If the variable has a 'shape' attribute (like NumPy arrays or SymPy matrices), show shape
        elif hasattr(var, 'shape'):
            print(f"  Shape:                                 {var.shape}")
            element_types = get_element_types(var)
            print(f"  Element Types:                        {element_types}")
        
        else:
            print(f"  Shape:                                 lemeow~")
        
        print(f"  Value:                                 {var}\n")

# Example code based on the symbols you've provided
L = 80
S = L * 2
n = 41
I = 7**2

# SymPy symbols and expressions
t, tau, kd, alpha = sp.symbols('t tau kd alpha', real=True)
v = sp.symbols(f"v0:{n}", real=True)  # Define v as a list of symbols
k = sp.symbols(f"k0:{n}", real=True)
kappa = sp.symbols(f"kappa0:{n}", real=True)
ar = sp.symbols(f"ar0:{L}", real=True)
ai = sp.symbols(f"ai0:{L}", real=True)
br = sp.symbols(f"br0:{L}", real=True)
bi = sp.symbols(f"bi0:{L}", real=True)

# Define complex elements aa, aac, bb, bbc
aa = [ar[i] + sp.I * ai[i] for i in range(L)]
aac = [ar[i] - sp.I * ai[i] for i in range(L)]
bb = [br[i] + sp.I * bi[i] for i in range(L)]
bbc = [br[i] - sp.I * bi[i] for i in range(L)]

# Constructing a matrix for `ts`
ts = sp.Matrix([aa[i // 2] if i % 2 == 0 else bb[i // 2] for i in range(2 * L)])

# Call the function to test the types inside this matrix
gl(ts)
# Out:
# Name:                                  'ts'
#   Type:                                  MutableDenseMatrix
#   Shape:                                 (160, 1)
# Analyzing: I*ai0 + ar0 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar0 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar0 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai0 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai0 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai0 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai0 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi0 + br0 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br0 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br0 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi0 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi0 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi0 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi0 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai1 + ar1 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar1 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar1 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai1 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai1 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai1 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai1 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi1 + br1 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br1 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br1 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi1 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi1 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi1 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi1 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai2 + ar2 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar2 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar2 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai2 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai2 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai2 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai2 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi2 + br2 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br2 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br2 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi2 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi2 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi2 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi2 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai3 + ar3 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar3 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar3 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai3 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai3 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai3 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai3 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi3 + br3 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br3 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br3 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi3 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi3 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi3 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi3 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai4 + ar4 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar4 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar4 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai4 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai4 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai4 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai4 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi4 + br4 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br4 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br4 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi4 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi4 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi4 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi4 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai5 + ar5 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar5 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar5 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai5 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai5 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai5 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai5 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi5 + br5 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br5 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br5 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi5 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi5 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi5 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi5 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai6 + ar6 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar6 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar6 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai6 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai6 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai6 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai6 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi6 + br6 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br6 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br6 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi6 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi6 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi6 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi6 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai7 + ar7 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar7 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar7 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai7 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai7 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai7 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai7 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi7 + br7 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br7 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br7 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi7 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi7 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi7 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi7 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai8 + ar8 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar8 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar8 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai8 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai8 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai8 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai8 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi8 + br8 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br8 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br8 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi8 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi8 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi8 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi8 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai9 + ar9 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar9 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar9 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai9 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai9 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai9 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai9 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi9 + br9 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br9 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br9 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi9 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi9 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi9 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi9 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai10 + ar10 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar10 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar10 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai10 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai10 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai10 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai10 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi10 + br10 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br10 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br10 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi10 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi10 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi10 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi10 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai11 + ar11 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar11 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar11 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai11 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai11 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai11 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai11 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi11 + br11 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br11 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br11 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi11 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi11 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi11 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi11 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai12 + ar12 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar12 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar12 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai12 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai12 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai12 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai12 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi12 + br12 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br12 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br12 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi12 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi12 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi12 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi12 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai13 + ar13 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar13 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar13 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai13 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai13 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai13 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai13 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi13 + br13 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br13 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br13 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi13 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi13 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi13 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi13 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai14 + ar14 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar14 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar14 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai14 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai14 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai14 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai14 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi14 + br14 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br14 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br14 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi14 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi14 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi14 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi14 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai15 + ar15 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar15 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar15 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai15 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai15 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai15 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai15 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi15 + br15 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br15 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br15 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi15 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi15 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi15 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi15 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai16 + ar16 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar16 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar16 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai16 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai16 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai16 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai16 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi16 + br16 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br16 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br16 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi16 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi16 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi16 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi16 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai17 + ar17 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar17 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar17 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai17 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai17 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai17 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai17 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi17 + br17 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br17 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br17 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi17 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi17 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi17 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi17 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai18 + ar18 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar18 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar18 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai18 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai18 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai18 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai18 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi18 + br18 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br18 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br18 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi18 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi18 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi18 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi18 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai19 + ar19 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar19 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar19 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai19 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai19 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai19 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai19 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi19 + br19 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br19 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br19 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi19 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi19 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi19 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi19 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai20 + ar20 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar20 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar20 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai20 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai20 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai20 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai20 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi20 + br20 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br20 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br20 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi20 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi20 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi20 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi20 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai21 + ar21 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar21 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar21 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai21 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai21 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai21 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai21 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi21 + br21 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br21 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br21 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi21 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi21 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi21 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi21 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai22 + ar22 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar22 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar22 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai22 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai22 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai22 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai22 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi22 + br22 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br22 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br22 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi22 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi22 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi22 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi22 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai23 + ar23 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar23 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar23 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai23 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai23 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai23 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai23 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi23 + br23 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br23 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br23 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi23 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi23 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi23 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi23 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai24 + ar24 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar24 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar24 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai24 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai24 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai24 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai24 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi24 + br24 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br24 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br24 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi24 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi24 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi24 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi24 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai25 + ar25 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar25 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar25 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai25 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai25 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai25 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai25 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi25 + br25 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br25 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br25 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi25 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi25 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi25 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi25 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai26 + ar26 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar26 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar26 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai26 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai26 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai26 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai26 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi26 + br26 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br26 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br26 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi26 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi26 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi26 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi26 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai27 + ar27 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar27 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar27 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai27 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai27 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai27 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai27 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi27 + br27 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br27 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br27 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi27 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi27 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi27 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi27 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai28 + ar28 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar28 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar28 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai28 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai28 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai28 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai28 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi28 + br28 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br28 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br28 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi28 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi28 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi28 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi28 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai29 + ar29 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar29 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar29 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai29 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai29 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai29 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai29 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi29 + br29 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br29 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br29 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi29 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi29 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi29 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi29 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai30 + ar30 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar30 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar30 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai30 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai30 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai30 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai30 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi30 + br30 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br30 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br30 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi30 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi30 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi30 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi30 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai31 + ar31 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar31 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar31 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai31 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai31 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai31 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai31 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi31 + br31 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br31 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br31 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi31 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi31 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi31 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi31 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai32 + ar32 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar32 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar32 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai32 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai32 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai32 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai32 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi32 + br32 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br32 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br32 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi32 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi32 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi32 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi32 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai33 + ar33 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar33 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar33 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai33 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai33 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai33 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai33 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi33 + br33 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br33 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br33 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi33 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi33 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi33 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi33 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai34 + ar34 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar34 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar34 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai34 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai34 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai34 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai34 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi34 + br34 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br34 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br34 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi34 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi34 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi34 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi34 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai35 + ar35 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar35 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar35 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai35 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai35 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai35 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai35 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi35 + br35 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br35 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br35 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi35 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi35 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi35 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi35 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai36 + ar36 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar36 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar36 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai36 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai36 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai36 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai36 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi36 + br36 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br36 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br36 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi36 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi36 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi36 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi36 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai37 + ar37 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar37 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar37 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai37 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai37 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai37 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai37 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi37 + br37 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br37 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br37 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi37 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi37 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi37 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi37 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai38 + ar38 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar38 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar38 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai38 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai38 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai38 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai38 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi38 + br38 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br38 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br38 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi38 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi38 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi38 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi38 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai39 + ar39 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar39 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar39 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai39 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai39 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai39 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai39 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi39 + br39 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br39 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br39 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi39 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi39 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi39 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi39 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai40 + ar40 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar40 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar40 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai40 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai40 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai40 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai40 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi40 + br40 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br40 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br40 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi40 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi40 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi40 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi40 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai41 + ar41 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar41 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar41 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai41 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai41 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai41 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai41 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi41 + br41 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br41 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br41 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi41 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi41 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi41 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi41 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai42 + ar42 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar42 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar42 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai42 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai42 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai42 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai42 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi42 + br42 of type <class 'sympy.core.add.Add'>
# ...
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi71 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi71 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai72 + ar72 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar72 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar72 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai72 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai72 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai72 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai72 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi72 + br72 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br72 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br72 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi72 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi72 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi72 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi72 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai73 + ar73 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar73 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar73 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai73 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai73 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai73 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai73 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi73 + br73 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br73 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br73 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi73 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi73 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi73 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi73 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai74 + ar74 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar74 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar74 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai74 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai74 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai74 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai74 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi74 + br74 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br74 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br74 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi74 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi74 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi74 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi74 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai75 + ar75 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar75 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar75 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai75 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai75 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai75 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai75 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi75 + br75 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br75 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br75 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi75 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi75 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi75 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi75 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai76 + ar76 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar76 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar76 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai76 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai76 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai76 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai76 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi76 + br76 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br76 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br76 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi76 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi76 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi76 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi76 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai77 + ar77 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar77 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar77 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai77 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai77 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai77 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai77 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi77 + br77 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br77 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br77 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi77 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi77 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi77 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi77 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai78 + ar78 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar78 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar78 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai78 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai78 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai78 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai78 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi78 + br78 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br78 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br78 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi78 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi78 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi78 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi78 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*ai79 + ar79 of type <class 'sympy.core.add.Add'>
#   Sub-expression: ar79 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ar79 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*ai79 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*ai79 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: ai79 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: ai79 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: I*bi79 + br79 of type <class 'sympy.core.add.Add'>
#   Sub-expression: br79 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: br79 of type <class 'sympy.core.symbol.Symbol'>
#   Sub-expression: I*bi79 of type <class 'sympy.core.mul.Mul'>
# Analyzing: I*bi79 of type <class 'sympy.core.mul.Mul'>
#   Sub-expression: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
# Analyzing: I of type <class 'sympy.core.numbers.ImaginaryUnit'>
#   Sub-expression: bi79 of type <class 'sympy.core.symbol.Symbol'>
# Analyzing: bi79 of type <class 'sympy.core.symbol.Symbol'>
#   Element Types:                        {'Symbol(br69)', 'Symbol(bi23)', 'Symbol(br21)', 'Symbol(ar57)', 'Symbol(bi6)', 'Symbol(bi77)', 'Symbol(bi74)', 'Symbol(br64)', 'Symbol(ai9)', 'Symbol(ar53)', 'Symbol(bi21)', 'Symbol(bi13)', 'Symbol(bi42)', 'Symbol(ar11)', 'Symbol(bi36)', 'Symbol(br8)', 'Symbol(br6)', 'Symbol(ai57)', 'Symbol(ai25)', 'Symbol(ai35)', 'Symbol(ar19)', 'Symbol(ar68)', '